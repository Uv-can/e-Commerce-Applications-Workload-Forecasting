# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.figsize']=10,6
import csv
import numpy as np
import math

# %%
df2=pd.read_csv('final_input_file.csv')
#df2

# %% [markdown]
# # Visualizing Dataset

# %%
fig=plt.figure(figsize=(12,8))
plt.title("Task vs Time")
plt.xlabel("Time interval")
plt.ylabel("Number of instances")
plt.plot(df2.time_interval, df2.no_of_instances)
plt.show()

# %%
#Computational Time
import time
time_start = time.clock()

#Code
a1=0.1
a2=0.1
a3=0.1
a4=0.1
a5=0.6

X = df2.no_of_instances
Begin=5
predictions=list()
times=list()
SE=0
sumAPE=0
#sumMASE=0
#test=[X[i] for i in range(Begin,len(X)]
for i in range (Begin,len(X)):
    Ft=np.int(a1*df2.no_of_instances[i-5]+a2*df2.no_of_instances[i-4]+a3*df2.no_of_instances[i-3]+a4*df2.no_of_instances[i-2]+a5*df2.no_of_instances[i-1])
    predictions.append(Ft)
    Ft_prev=Ft
    times.append(df2.time_interval[i])
    print('Time, predicted, expected \n',df2.time_interval[i], Ft, df2.no_of_instances[i])
    e=abs(Ft-df2.no_of_instances[i])
    SE=SE+e*e
    APE=abs((Ft-df2.no_of_instances[i])/df2.no_of_instances[i])
    sumAPE=sumAPE+APE
    #ASE=abs((yhat-obs)/(test[t]-df2.no_of_instances[t-1]))
    #sumMASE=sumMASE+ASE
RMSE=math.sqrt(SE/len(X)-Begin)
MAPE=(sumAPE/(len(X)-Begin))*100
#MASE=(sumMASE/(len(X)))
print('RMSE Value= ', RMSE)
print('MAPE Value= ', MAPE)
#print('MASE Value= ', MASE)
    
#print('Time= \n', times)
#print('Predictions= \n', predictions)

#Computational Time
time_elapsed = (time.clock() - time_start)
print('Computational Time=', time_elapsed)

# plot
fig=plt.figure(figsize=(12,8))
plt.title("Predicted vs Expected- - Weighted Moving Average")
plt.xlabel("Time interval")
plt.ylabel("Number of instances")
plt.plot(times, predictions, color='red', label='Predicted', linestyle='solid')
plt.scatter(df2.time_interval, df2.no_of_instances, color='blue', label='Original')
plt.legend()
plt.show()
# Out:
# C:\Users\Uvcan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# Time, predicted, expected
#  15 9254 8375
# Time, predicted, expected
#  18 12100 14431
# Time, predicted, expected
#  21 9926 29231
# Time, predicted, expected
#  24 20249 26181
# Time, predicted, expected
#  27 21342 62225
# Time, predicted, expected
#  30 45156 16371
# Time, predicted, expected
#  33 23029 13337
# Time, predicted, expected
#  36 21403 24957
# Time, predicted, expected
#  39 26785 22465
# Time, predicted, expected
#  42 25168 33509
# Time, predicted, expected
#  45 27818 27614
# Time, predicted, expected
#  48 25995 37844
# Time, predicted, expected
#  51 33560 29999
# Time, predicted, expected
#  54 30142 18792
# Time, predicted, expected
#  57 24171 97007
# Time, predicted, expected
#  60 69629 69360
# Time, predicted, expected
#  63 59980 58208
# Time, predicted, expected
#  66 56440 30980
# Time, predicted, expected
#  69 42924 24095
# Time, predicted, expected
#  72 40012 15465
# Time, predicted, expected
#  75 27543 47854
# Time, predicted, expected
#  78 41587 28770
# Time, predicted, expected
#  81 29101 31513
# Time, predicted, expected
#  84 30526 8024
# Time, predicted, expected
#  87 17174 21380
# Time, predicted, expected
#  90 24444 20513
# Time, predicted, expected
#  93 21276 19727
# Time, predicted, expected
#  96 19979 8616
# Time, predicted, expected
#  99 12134 21318
# Time, predicted, expected
#  102 19814 59174
# Time, predicted, expected
#  105 42521 11699
# Time, predicted, expected
#  108 17902 32231
# Time, predicted, expected
#  111 29419 12084
# Time, predicted, expected
#  114 19692 32034
# Time, predicted, expected
#  117 30739 33136
# Time, predicted, expected
#  120 28686 49765
# Time, predicted, expected
#  123 40807 54757
# Time, predicted, expected
#  126 45556 95694
# Time, predicted, expected
#  129 74385 23541
# Time, predicted, expected
#  132 37459 6002
# Time, predicted, expected
#  135 25976 4667
# Time, predicted, expected
#  138 20799 30193
# Time, predicted, expected
#  141 31106 77322
# Time, predicted, expected
#  144 52833 7434
# Time, predicted, expected
#  147 16278 5601
# Time, predicted, expected
#  150 15322 19395
# Time, predicted, expected
#  153 23692 16847
# Time, predicted, expected
#  156 21083 47515
# Time, predicted, expected
#  159 33436 37272
# Time, predicted, expected
#  162 31299 46597
# Time, predicted, expected
#  165 40061 11486
# Time, predicted, expected
#  168 21714 45456
# Time, predicted, expected
#  171 41560 43106
# Time, predicted, expected
#  174 39944 39493
# Time, predicted, expected
#  177 38360 76652
# Time, predicted, expected
#  180 59945 52900
# Time, predicted, expected
#  183 52210 17585
# Time, predicted, expected
#  186 31766 59317
# Time, predicted, expected
#  189 54253 5150
# Time, predicted, expected
#  192 23735 4376
# Time, predicted, expected
#  195 16120 42933
# Time, predicted, expected
#  198 34402 59398
# Time, predicted, expected
#  201 46816 48180
# Time, predicted, expected
#  204 40093 42183
# Time, predicted, expected
#  207 40798 14211
# Time, predicted, expected
#  210 27796 13021
# Time, predicted, expected
#  213 24209 30710
# Time, predicted, expected
#  216 30185 11928
# Time, predicted, expected
#  219 17169 12740
# Time, predicted, expected
#  222 14631 37376
# Time, predicted, expected
#  225 29265 41045
# Time, predicted, expected
#  228 33902 52461
# Time, predicted, expected
#  231 41785 46252
# Time, predicted, expected
#  234 42113 58242
# Time, predicted, expected
#  237 52658 10176
# Time, predicted, expected
#  240 25905 22349
# Time, predicted, expected
#  243 30122 13912
# Time, predicted, expected
#  246 22049 23091
# Time, predicted, expected
#  249 24322 50146
# Time, predicted, expected
#  252 37040 38168
# Time, predicted, expected
#  255 33850 64517
# Time, predicted, expected
#  258 51241 54856
# Time, predicted, expected
#  261 50505 29958
# Time, predicted, expected
#  264 38743 26832
# Time, predicted, expected
#  267 34849 5569
# Time, predicted, expected
#  270 20957 26719
# Time, predicted, expected
#  273 27752 9405
# Time, predicted, expected
#  276 14550 24297
# Time, predicted, expected
#  279 21430 41404
# Time, predicted, expected
#  282 31441 28757
# Time, predicted, expected
#  285 27436 16047
# Time, predicted, expected
#  288 20014 62489
# Time, predicted, expected
#  291 48543 58318
# Time, predicted, expected
#  294 49860 28864
# Time, predicted, expected
#  297 33879 37374
# Time, predicted, expected
#  300 38996 12757
# Time, predicted, expected
#  303 26358 31646
# Time, predicted, expected
#  306 32718 66641
# Time, predicted, expected
#  309 51048 126806
# Time, predicted, expected
#  312 90925 35567
# Time, predicted, expected
#  315 45125 11270
# Time, predicted, expected
#  318 32828 15361
# Time, predicted, expected
#  321 33245 30186
# Time, predicted, expected
#  324 37012 17548
# Time, predicted, expected
#  327 19767 20571
# Time, predicted, expected
#  330 19779 26154
# Time, predicted, expected
#  333 24059 18873
# Time, predicted, expected
#  336 20769 918
# Time, predicted, expected
#  339 8865 773
# Time, predicted, expected
#  342 7115 1789
# Time, predicted, expected
#  345 5745 16304
# Time, predicted, expected
#  348 12017 40339
# Time, predicted, expected
#  351 26181 28245
# Time, predicted, expected
#  354 22867 60707
# Time, predicted, expected
#  357 45091 22611
# Time, predicted, expected
#  360 28126 30905
# Time, predicted, expected
#  363 33733 18323
# Time, predicted, expected
#  366 25240 142154
# Time, predicted, expected
#  369 98547 873
# Time, predicted, expected
#  372 21923 1846
# Time, predicted, expected
#  375 20333 12247
# Time, predicted, expected
#  378 23667 94325
# Time, predicted, expected
#  381 72307 72507
# Time, predicted, expected
#  384 54433 3943
# Time, predicted, expected
#  387 20458 6292
# Time, predicted, expected
#  390 22077 23554
# Time, predicted, expected
#  393 31839 46424
# Time, predicted, expected
#  396 38484 30066
# Time, predicted, expected
#  399 26060 10397
# Time, predicted, expected
#  402 16871 11868
# Time, predicted, expected
#  405 18164 64454
# Time, predicted, expected
#  408 48547 18594
# Time, predicted, expected
#  411 22834 2969
# Time, predicted, expected
#  414 12312 12733
# Time, predicted, expected
#  417 17428 92343
# Time, predicted, expected
#  420 65280 51790
# Time, predicted, expected
#  423 43737 30244
# Time, predicted, expected
#  426 34129 28365
# Time, predicted, expected
#  429 35730 38503
# Time, predicted, expected
#  432 43376 10776
# Time, predicted, expected
#  435 21355 57886
# Time, predicted, expected
#  438 45520 24907
# Time, predicted, expected
#  441 28497 40031
# Time, predicted, expected
#  444 37225 16433
# Time, predicted, expected
#  447 23219 19428
# Time, predicted, expected
#  450 25582 45368
# Time, predicted, expected
#  453 37300 29980
# Time, predicted, expected
#  456 30114 12016
# Time, predicted, expected
#  459 18330 15990
# Time, predicted, expected
#  462 20273 12670
# Time, predicted, expected
#  465 17937 22035
# Time, predicted, expected
#  468 20286 28741
# Time, predicted, expected
#  471 23515 35414
# Time, predicted, expected
#  474 29192 10341
# Time, predicted, expected
#  477 16090 28750
# Time, predicted, expected
#  480 26903 17004
# Time, predicted, expected
#  483 20527 57959
# Time, predicted, expected
#  486 43926 58835
# Time, predicted, expected
#  489 46706 15115
# Time, predicted, expected
#  492 25323 18
# Time, predicted, expected
#  495 14902 10754
# Time, predicted, expected
#  498 19645 9446
# Time, predicted, expected
#  501 14139 21531
# Time, predicted, expected
#  504 16451 22431
# Time, predicted, expected
#  507 17633 14152
# Time, predicted, expected
#  510 14907 35097
# Time, predicted, expected
#  513 27814 39840
# Time, predicted, expected
#  516 33225 8054
# Time, predicted, expected
#  519 15984 14702
# Time, predicted, expected
#  522 18535 10337
# Time, predicted, expected
#  525 15971 6328
# Time, predicted, expected
#  528 11090 52727
# Time, predicted, expected
#  531 35578 31366
# Time, predicted, expected
#  534 27229 35574
# Time, predicted, expected
#  537 31420 15513
# Time, predicted, expected
#  540 21907 91827
# Time, predicted, expected
#  543 68614 12130
# Time, predicted, expected
#  546 24706 42528
# Time, predicted, expected
#  549 41021 2308
# Time, predicted, expected
#  552 17584 26047
# Time, predicted, expected
#  555 30507 2794
# Time, predicted, expected
#  558 9977 6917
# Time, predicted, expected
#  561 11517 19870
# Time, predicted, expected
#  564 15728 8506
# Time, predicted, expected
#  567 10666 23612
# Time, predicted, expected
#  570 17975 39105
# Time, predicted, expected
#  573 29353 30508
# Time, predicted, expected
#  576 27414 6647
# Time, predicted, expected
#  579 14161 3853
# Time, predicted, expected
#  582 12299 33155
# Time, predicted, expected
#  585 27904 12295
# Time, predicted, expected
#  588 14793 15017
# Time, predicted, expected
#  591 14605 12407
# Time, predicted, expected
#  594 13876 26772
# Time, predicted, expected
#  597 23350 13421
# Time, predicted, expected
#  600 14701 27933
# Time, predicted, expected
#  603 23521 24248
# Time, predicted, expected
#  606 22602 9403
# Time, predicted, expected
#  609 14879 27316
# Time, predicted, expected
#  612 23890 26894
# Time, predicted, expected
#  615 25026 17455
# Time, predicted, expected
#  618 19259 55126
# Time, predicted, expected
#  621 41182 4087
# Time, predicted, expected
#  624 15131 24162
# Time, predicted, expected
#  627 24853 10927
# Time, predicted, expected
#  630 16639 44160
# Time, predicted, expected
#  633 35926 52160
# Time, predicted, expected
#  636 39629 9281
# Time, predicted, expected
#  639 18709 21783
# Time, predicted, expected
#  642 24722 25457
# Time, predicted, expected
#  645 28012 26051
# Time, predicted, expected
#  648 26498 25283
# Time, predicted, expected
#  651 23427 14035
# Time, predicted, expected
#  654 18278 15388
# Time, predicted, expected
#  657 18315 18667
# Time, predicted, expected
#  660 19275 17179
# Time, predicted, expected
#  663 17644 36142
# Time, predicted, expected
#  666 28212 21670
# Time, predicted, expected
#  669 21739 30017
# Time, predicted, expected
#  672 27376 50175
# Time, predicted, expected
#  675 40605 32833
# Time, predicted, expected
#  678 33500 3486
# Time, predicted, expected
#  681 15561 23640
# Time, predicted, expected
#  684 25835 15839
# Time, predicted, expected
#  687 20516 30368
# Time, predicted, expected
#  690 25800 15484
# Time, predicted, expected
#  693 16623 29322
# Time, predicted, expected
#  696 26126 33343
# Time, predicted, expected
#  699 29107 21100
# Time, predicted, expected
#  702 23511 55211
# Time, predicted, expected
#  705 43051 53157
# Time, predicted, expected
#  708 45791 64017
# Time, predicted, expected
#  711 54691 52712
# Time, predicted, expected
#  714 50975 53887
# Time, predicted, expected
#  717 54841 51242
# Time, predicted, expected
#  720 53122 53711
# Time, predicted, expected
#  723 54412 24971
# Time, predicted, expected
#  726 36137 75941
# Time, predicted, expected
#  729 63945 20287
# Time, predicted, expected
#  732 32758 53960
# Time, predicted, expected
#  735 49867 42561
# Time, predicted, expected
#  738 43052 42928
# Time, predicted, expected
#  741 45031 91973
# Time, predicted, expected
#  744 71157 36017
# Time, predicted, expected
#  747 44752 72362
# Time, predicted, expected
#  750 64765 19660
# Time, predicted, expected
#  753 36124 35256
# Time, predicted, expected
#  756 43154 24156
# Time, predicted, expected
#  759 30823 57451
# Time, predicted, expected
#  762 49614 38270
# Time, predicted, expected
#  765 36614 11117
# Time, predicted, expected
#  768 22183 64903
# Time, predicted, expected
#  771 52041 60965
# Time, predicted, expected
#  774 53753 66251
# Time, predicted, expected
#  777 57276 27533
# Time, predicted, expected
#  780 36843 45872
# Time, predicted, expected
#  783 49488 47244
# Time, predicted, expected
#  786 48408 27305
# Time, predicted, expected
#  789 35073 40015
# Time, predicted, expected
#  792 38804 35776
# Time, predicted, expected
#  795 37509 39418
# Time, predicted, expected
#  798 38684 104912
# Time, predicted, expected
#  801 77198 73958
# Time, predicted, expected
#  804 66386 43559
# Time, predicted, expected
#  807 51541 32867
# Time, predicted, expected
#  810 45904 50236
# Time, predicted, expected
#  813 55671 27735
# Time, predicted, expected
#  816 36703 48646
# Time, predicted, expected
#  819 44627 17227
# Time, predicted, expected
#  822 26284 75695
# Time, predicted, expected
#  825 59801 89404
# Time, predicted, expected
#  828 70572 14633
# Time, predicted, expected
#  831 31876 259887
# Time, predicted, expected
#  834 175628 125832
# Time, predicted, expected
#  837 119461 66533
# Time, predicted, expected
#  840 88895 35993
# Time, predicted, expected
#  843 68284 49375
# Time, predicted, expected
#  846 78449 101400
# Time, predicted, expected
#  849 88613 60457
# Time, predicted, expected
#  852 61604 45092
# Time, predicted, expected
#  855 51777 65475
# Time, predicted, expected
#  858 64917 64705
# Time, predicted, expected
#  861 66065 74241
# Time, predicted, expected
#  864 68117 71728
# Time, predicted, expected
#  867 67988 78135
# Time, predicted, expected
#  870 74495 38759
# Time, predicted, expected
#  873 52136 73167
# Time, predicted, expected
#  876 70186 17094
# Time, predicted, expected
#  879 36435 367838
# Time, predicted, expected
#  882 241418 23384
# Time, predicted, expected
#  885 63716 66751
# Time, predicted, expected
#  888 88198 29636
# Time, predicted, expected
#  891 65288 70221
# Time, predicted, expected
#  894 90893 225655
# Time, predicted, expected
#  897 154392 66359
# Time, predicted, expected
#  900 79041 63774
# Time, predicted, expected
#  903 77451 49842
# Time, predicted, expected
#  906 72506 17935
# Time, predicted, expected
#  909 51324 36447
# Time, predicted, expected
#  912 41659 31877
# Time, predicted, expected
#  915 35926 30346
# Time, predicted, expected
#  918 31817 57782
# Time, predicted, expected
#  921 46329 18041
# Time, predicted, expected
#  924 26469 17381
# Time, predicted, expected
#  927 24233 29285
# Time, predicted, expected
#  930 29926 22680
# Time, predicted, expected
#  933 25856 46370
# Time, predicted, expected
#  936 36560 39218
# Time, predicted, expected
#  939 35102 52644
# Time, predicted, expected
#  942 45341 61374
# Time, predicted, expected
#  945 52915 49980
# Time, predicted, expected
#  948 49948 52809
# Time, predicted, expected
#  951 52007 10444
# Time, predicted, expected
#  954 27947 24337
# Time, predicted, expected
#  957 32062 24861
# Time, predicted, expected
#  960 28673 6261
# Time, predicted, expected
#  963 15001 14938
# Time, predicted, expected
#  966 15553 2901
# Time, predicted, expected
#  969 8780 13373
# Time, predicted, expected
#  972 12919 6773
# Time, predicted, expected
#  975 7811 22049
# Time, predicted, expected
#  978 17027 8940
# Time, predicted, expected
#  981 9873 33748
# Time, predicted, expected
#  984 25362 18144
# Time, predicted, expected
#  987 18037 15930
# Time, predicted, expected
#  990 17846 22801
# Time, predicted, expected
#  993 21356 31749
# Time, predicted, expected
#  996 28111 7179
# Time, predicted, expected
#  999 13169 16547
# Time, predicted, expected
#  1002 17694 15646
# Time, predicted, expected
#  1005 17215 4204
# Time, predicted, expected
#  1008 9634 7557
# Time, predicted, expected
#  1011 8891 10224
# Time, predicted, expected
#  1014 10529 124
# Time, predicted, expected
#  1017 3837 1
# RMSE Value=  35745.17496476643
# MAPE Value=  1733.9274967739589
# Computational Time= 0.311996599950362
# C:\Users\Uvcan\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
